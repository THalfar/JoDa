# %%
# Kaggle [Data Cleaning course](https://www.kaggle.com/learn/data-cleaning)

# %%
import pandas as pd 
import numpy as np

nfl_data = pd.read_csv("./data/NFL Play by Play 2009-2016 (v3).csv")
# Out:
# /tmp/ipykernel_569016/1931636337.py:4: DtypeWarning: Columns (25,51) have mixed types. Specify dtype option on import or set low_memory=False.
#   nfl_data = pd.read_csv("./data/NFL Play by Play 2009-2016 (v3).csv")
#          Date      GameID  Drive  qtr  down   time  TimeUnder  TimeSecs  \
# 0  2009-09-10  2009091000      1    1   NaN  15:00         15    3600.0
# 1  2009-09-10  2009091000      1    1   1.0  14:53         15    3593.0
# 2  2009-09-10  2009091000      1    1   2.0  14:16         15    3556.0
# 3  2009-09-10  2009091000      1    1   3.0  13:35         14    3515.0
# 4  2009-09-10  2009091000      1    1   4.0  13:27         14    3507.0
#
#    PlayTimeDiff SideofField  ...    yacEPA  Home_WP_pre  Away_WP_pre  \
# 0           0.0         TEN  ...       NaN     0.485675     0.514325
# 1           7.0         PIT  ...  1.146076     0.546433     0.453567
# 2          37.0         PIT  ...       NaN     0.551088     0.448912
# ...

# %%
nfl_data.head()
# Out:
#          Date      GameID  Drive  qtr  down   time  TimeUnder  TimeSecs  \
# 0  2009-09-10  2009091000      1    1   NaN  15:00         15    3600.0
# 1  2009-09-10  2009091000      1    1   1.0  14:53         15    3593.0
# 2  2009-09-10  2009091000      1    1   2.0  14:16         15    3556.0
# 3  2009-09-10  2009091000      1    1   3.0  13:35         14    3515.0
# 4  2009-09-10  2009091000      1    1   4.0  13:27         14    3507.0
#
#    PlayTimeDiff SideofField  ...    yacEPA  Home_WP_pre  Away_WP_pre  \
# 0           0.0         TEN  ...       NaN     0.485675     0.514325
# 1           7.0         PIT  ...  1.146076     0.546433     0.453567
# 2          37.0         PIT  ...       NaN     0.551088     0.448912
# 3          41.0         PIT  ... -5.031425     0.510793     0.489207
# 4           8.0         PIT  ...       NaN     0.461217     0.538783
#
#    Home_WP_post  Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  Season
# ...

# %%
missing_values_count = nfl_data.isnull().sum()
missing_values_count[:10]
# Out:
# Date                0
# GameID              0
# Drive               0
# qtr                 0
# down            54218
# time              188
# TimeUnder           0
# TimeSecs          188
# PlayTimeDiff      374
# SideofField       450
# dtype: int64

# %%
tolal_cells = np.product(nfl_data.shape)
total_missing = missing_values_count.sum()

percentage_missing = (total_missing / tolal_cells) * 100
print(f"Missing data : {percentage_missing:.2f}%")
# Out:
# Missing : 27.65%

# %%
nfl_data.dropna()
# Out:
# Empty DataFrame
# ...

# %%
columns_with_na_dropped = nfl_data.dropna(axis=1)
columns_with_na_dropped.head()
# Out:
#          Date      GameID  Drive  qtr  TimeUnder  ydstogo  ydsnet  \
# 0  2009-09-10  2009091000      1    1         15        0       0
# 1  2009-09-10  2009091000      1    1         15       10       5
# 2  2009-09-10  2009091000      1    1         15        5       2
# 3  2009-09-10  2009091000      1    1         14        8       2
# 4  2009-09-10  2009091000      1    1         14        8       2
#
#    PlayAttempted  Yards.Gained  sp  ...  AwayTeam  Timeout_Indicator  \
# 0              1            39   0  ...       TEN                  0
# 1              1             5   0  ...       TEN                  0
# 2              1            -3   0  ...       TEN                  0
# 3              1             0   0  ...       TEN                  0
# 4              1             0   0  ...       TEN                  0
#
#    posteam_timeouts_pre HomeTimeouts_Remaining_Pre  \
# 0                     3                          3
# ...

# %%
print("Columns in original data : %d" % nfl_data.shape[1])
print("Columns with na's dropped : %d" % columns_with_na_dropped.shape[1])
# Out:
# Columns in original data : 102
# Columns with na's dropped : 37

# %%
subset_nfl_data = nfl_data.loc[:, 'EPA':'Season'].head()
subset_nfl_data
# Out:
#         EPA    airEPA    yacEPA  Home_WP_pre  Away_WP_pre  Home_WP_post  \
# 0  2.014474       NaN       NaN     0.485675     0.514325      0.546433
# 1  0.077907 -1.068169  1.146076     0.546433     0.453567      0.551088
# 2 -1.402760       NaN       NaN     0.551088     0.448912      0.510793
# 3 -1.712583  3.318841 -5.031425     0.510793     0.489207      0.461217
# 4  2.097796       NaN       NaN     0.461217     0.538783      0.558929
#
#    Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  Season
# 0      0.453567  0.485675  0.060758       NaN       NaN    2009
# 1      0.448912  0.546433  0.004655 -0.032244  0.036899    2009
# 2      0.489207  0.551088 -0.040295       NaN       NaN    2009
# 3      0.538783  0.510793 -0.049576  0.106663 -0.156239    2009
# 4      0.441071  0.461217  0.097712       NaN       NaN    2009

# %%
subset_nfl_data.fillna(0)
# Out:
#         EPA    airEPA    yacEPA  Home_WP_pre  Away_WP_pre  Home_WP_post  \
# 0  2.014474  0.000000  0.000000     0.485675     0.514325      0.546433
# 1  0.077907 -1.068169  1.146076     0.546433     0.453567      0.551088
# 2 -1.402760  0.000000  0.000000     0.551088     0.448912      0.510793
# 3 -1.712583  3.318841 -5.031425     0.510793     0.489207      0.461217
# 4  2.097796  0.000000  0.000000     0.461217     0.538783      0.558929
#
#    Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  Season
# 0      0.453567  0.485675  0.060758  0.000000  0.000000    2009
# 1      0.448912  0.546433  0.004655 -0.032244  0.036899    2009
# 2      0.489207  0.551088 -0.040295  0.000000  0.000000    2009
# 3      0.538783  0.510793 -0.049576  0.106663 -0.156239    2009
# 4      0.441071  0.461217  0.097712  0.000000  0.000000    2009

# %%
subset_nfl_data.bfill().fillna(0)
# Out:
#         EPA    airEPA    yacEPA  Home_WP_pre  Away_WP_pre  Home_WP_post  \
# 0  2.014474 -1.068169  1.146076     0.485675     0.514325      0.546433
# 1  0.077907 -1.068169  1.146076     0.546433     0.453567      0.551088
# 2 -1.402760  3.318841 -5.031425     0.551088     0.448912      0.510793
# 3 -1.712583  3.318841 -5.031425     0.510793     0.489207      0.461217
# 4  2.097796  0.000000  0.000000     0.461217     0.538783      0.558929
#
#    Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  Season
# 0      0.453567  0.485675  0.060758 -0.032244  0.036899    2009
# 1      0.448912  0.546433  0.004655 -0.032244  0.036899    2009
# 2      0.489207  0.551088 -0.040295  0.106663 -0.156239    2009
# 3      0.538783  0.510793 -0.049576  0.106663 -0.156239    2009
# 4      0.441071  0.461217  0.097712  0.000000  0.000000    2009

# %%
building_permits = pd.read_csv("./data/Building_Permits.csv")
building_permits.head()
# Out:
# /tmp/ipykernel_569016/4035298570.py:1: DtypeWarning: Columns (22,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   building_permits = pd.read_csv("./data/Building_Permits.csv")
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 0           05/06/2015  0326  023            140                  NaN
# 1           04/19/2016  0306  007            440                  NaN
# 2           05/27/2016  0595  203           1647                  NaN
# 3           11/07/2016  0156  011           1230                  NaN
# ...

# %%
missing_values_count = building_permits.isnull().sum()
print(f"Missing values count : \n{missing_values_count}")
# Out:
# Missing values count :
# Permit Number                                  0
# Permit Type                                    0
# Permit Type Definition                         0
# Permit Creation Date                           0
# Block                                          0
# Lot                                            0
# Street Number                                  0
# Street Number Suffix                      196684
# Street Name                                    0
# Street Suffix                               2768
# Unit                                      169421
# Unit Suffix                               196939
# Description                                  290
# Current Status                                 0
# Current Status Date                            0
# Filed Date                                     0
# Issued Date                                14940
# Completed Date                            101709
# First Construction Document Date           14946
# ...

# %%
# Paljonko puuttuvia arvoja
missing_values_percent = (missing_values_count / np.product(building_permits.shape)) * 100
print(f"Missing values percent : \n{missing_values_percent}")
# Out:
# Missing values percent :
# Permit Number                             0.000000
# Permit Type                               0.000000
# Permit Type Definition                    0.000000
# Permit Creation Date                      0.000000
# Block                                     0.000000
# Lot                                       0.000000
# Street Number                             0.000000
# Street Number Suffix                      2.299671
# Street Name                               0.000000
# Street Suffix                             0.032364
# Unit                                      1.980907
# Unit Suffix                               2.302653
# Description                               0.003391
# Current Status                            0.000000
# Current Status Date                       0.000000
# Filed Date                                0.000000
# Issued Date                               0.174682
# Completed Date                            1.189203
# ...

# %%
# Katsotaan vain niitä arvoja joissa on puuttuvia arvoja
missing_values_percent_non_zero = missing_values_percent[missing_values_percent > 0]
print(f"Missing values percent non zero : \n{missing_values_percent_non_zero}")
# Out:
# Missing values percent non zero :
# Street Number Suffix                      2.299671
# Street Suffix                             0.032364
# Unit                                      1.980907
# Unit Suffix                               2.302653
# Description                               0.003391
# Issued Date                               0.174682
# Completed Date                            1.189203
# First Construction Document Date          0.174752
# Structural Notification                   2.244648
# Number of Existing Stories                0.500240
# Number of Proposed Stories                0.501222
# Voluntary Soft-Story Retrofit             2.325172
# Fire Only Permit                          2.105452
# Permit Expiration Date                    0.606592
# Estimated Cost                            0.445076
# Revised Cost                              0.070925
# Existing Use                              0.480714
# Existing Units                            0.602593
# ...

# %%
# Poistetaan ne sarakkeet joissa on puuttuvia arvoja
building_permits_na_dropped = building_permits.dropna(axis=1)
building_permits_na_dropped.head()  
print(f"Withoud dropping shape {building_permits.shape}")
print(f"After dropping null values: {building_permits_na_dropped.shape}")
# Out:
# Withoud dropping shape (198900, 43)
# After dropping null values: (198900, 12)

# %%
building_permits_missing_values_bfill = building_permits.fillna(method='bfill', axis=0).fillna(0)
print(f"Withoud filling values: {building_permits.shape}")
print(f"Building permits missing values bfill: {building_permits_missing_values_bfill.shape}")
# Out:
# /tmp/ipykernel_569016/2288509037.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   building_permits_missing_values_bfill = building_permits.fillna(method='bfill', axis=0).fillna(0)
# Withoud filling values: (198900, 43)
# Building permits missing values bfill: (198900, 43)

# %% [markdown]
# # Luku Scaling and Normalization

# %%
from scipy import stats 
from mlxtend.preprocessing import minmax_scaling
import seaborn as sns
import matplotlib.pyplot as plt

# generate 1000 data points randomly drawn from an exponential distribution
original_data = np.random.exponential(size=1000)

# mix-max scale the data between 0 and 1
scaled_data = minmax_scaling(original_data, columns=[0])

# plot both together to compare
fig, ax = plt.subplots(1, 2, figsize=(15, 3))
sns.histplot(original_data, ax=ax[0], kde=True, legend=False)
ax[0].set_title("Original Data")
sns.histplot(scaled_data, ax=ax[1], kde=True, legend=False)
ax[1].set_title("Scaled data")
plt.show()

# %%
# normalize the exponential data with boxcox
normalized_data = stats.boxcox(original_data)

# plot both together to compare
fig, ax=plt.subplots(1, 2, figsize=(15, 3))
sns.histplot(original_data, ax=ax[0], kde=True, legend=False)
ax[0].set_title("Original Data")
sns.histplot(normalized_data[0], ax=ax[1], kde=True, legend=False)
ax[1].set_title("Normalized data")
plt.show()

# %% [markdown]
# # Parsing date osuus

# %%
import datetime 

landslide_data = pd.read_csv("./data/catalog.csv")
landslide_data.head()
# Out:
#    id     date   time continent_code   country_name country_code  \
# 0  34   3/2/07  Night            NaN  United States           US
# 1  42  3/22/07    NaN            NaN  United States           US
# 2  56   4/6/07    NaN            NaN  United States           US
# 3  59  4/14/07    NaN            NaN         Canada           CA
# 4  61  4/15/07    NaN            NaN  United States           US
#
#   state/province  population         city/town  distance  ...  \
# 0       Virginia       16000       Cherry Hill   3.40765  ...
# 1           Ohio       17288  New Philadelphia   3.33522  ...
# 2   Pennsylvania       15930       Wilkinsburg   2.91977  ...
# 3         Quebec       42786       Châteauguay   2.98682  ...
# 4       Kentucky        6903         Pikeville   5.66542  ...
#
#                                  geolocation  hazard_type      landslide_type  \
# 0  (38.600900000000003, -77.268199999999993)    Landslide           Landslide
# ...

# %%
landslide_null_count = landslide_data.isnull().sum()

missing_values_percent = (landslide_null_count / np.product(landslide_data.shape)) * 100
print(f"Missing values percent : \n{missing_values_percent}")

missing_values_percent_non_zero = missing_values_percent[missing_values_percent > 0]
print(f"Missing values percent non zero : \n{missing_values_percent_non_zero}")
# Out:
# Missing values percent :
# id                      0.000000
# date                    0.007704
# time                    2.732479
# continent_code          3.926655
# country_name            0.000000
# country_code            0.000000
# state/province          0.002568
# population              0.000000
# city/town               0.010272
# distance                0.002568
# location_description    2.932792
# latitude                0.002568
# longitude               0.002568
# geolocation             0.002568
# hazard_type             0.000000
# landslide_type          0.002568
# landslide_size          0.002568
# trigger                 0.005136
# storm_name              4.008834
# injuries                3.025245
# fatalities              0.634325
# source_name             2.108426
# source_link             0.256812
# dtype: float64
# Missing values percent non zero :
# date                    0.007704
# time                    2.732479
# continent_code          3.926655
# ...

# %%
print(landslide_data['date'].head())
print(landslide_data['date'].dtype)
# Out:
# 0     3/2/07
# 1    3/22/07
# 2     4/6/07
# 3    4/14/07
# 4    4/15/07
# Name: date, dtype: object
# object

# %%
# Parsitaan päivämääräksi ja lisätään se sarakkeeksi
landslide_data['date_parsed'] = pd.to_datetime(landslide_data['date'], format="%m/%d/%y")
print(landslide_data.head())
print(landslide_data.keys())
# Out:
#    id     date   time continent_code   country_name country_code  \
# 0  34   3/2/07  Night            NaN  United States           US
# 1  42  3/22/07    NaN            NaN  United States           US
# 2  56   4/6/07    NaN            NaN  United States           US
# 3  59  4/14/07    NaN            NaN         Canada           CA
# 4  61  4/15/07    NaN            NaN  United States           US
#
#   state/province  population         city/town  distance  ... hazard_type  \
# 0       Virginia       16000       Cherry Hill   3.40765  ...   Landslide
# 1           Ohio       17288  New Philadelphia   3.33522  ...   Landslide
# 2   Pennsylvania       15930       Wilkinsburg   2.91977  ...   Landslide
# 3         Quebec       42786       Châteauguay   2.98682  ...   Landslide
# 4       Kentucky        6903         Pikeville   5.66542  ...   Landslide
#
#        landslide_type  landslide_size   trigger storm_name injuries  \
# ...

# %%
day_of_month_landslides = landslide_data['date_parsed'].dt.day
day_of_month_landslides.head()
# Out:
# 0     2.0
# 1    22.0
# 2     6.0
# 3    14.0
# 4    15.0
# Name: date_parsed, dtype: float64

# %%
# remove na's
day_of_month_landslides = day_of_month_landslides.dropna()

# plot the day of the month
sns.displot(day_of_month_landslides, kde=False, bins=31)
